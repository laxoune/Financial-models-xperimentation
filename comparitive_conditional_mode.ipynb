# %%
# Import the yfinance library, commonly aliased as yf
import yfinance as yf

# %%
ticker='AMZN'
df= yf.download(ticker, period='10y', interval='1d')
# Print the columns of the DataFrame to check for the 'Close' column
print(df.columns)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMZN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# MultiIndex([('Adj Close', 'AMZN'),
#             (    'Close', 'AMZN'),
#             (     'High', 'AMZN'),
#             (      'Low', 'AMZN'),
#             (     'Open', 'AMZN'),
#             (   'Volume', 'AMZN')],
#            names=['Price', 'Ticker'])
# Empty DataFrame
# Columns: [(Adj Close, AMZN), (Close, AMZN), (High, AMZN), (Low, AMZN), (Open, AMZN), (Volume, AMZN)]
# Index: []

# %%
# Access the 'Close' column using the MultiIndex tuple
weekly_data = df.resample('W').agg({('Close', 'AMZN'):['first','last']})
weekly_data.columns = ['start_of_week_price', 'end_of_week_price']
weekly_data['start_of_week'] = weekly_data.index - pd.offsets.Week(weekday=0)+pd.offsets.BDay(0)
weekly_data['end_of_week'] = weekly_data.index - pd.offsets.Week(weekday=4)+pd.offsets.BDay(0)
weekly_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 weekly_data = df.resample('W').agg({('Close', 'AMZN'):['first','last']})
#       3 weekly_data.columns = ['start_of_week_price', 'end_of_week_price']
# ----> 4 weekly_data['start_of_week'] = weekly_data.index - pd.offsets.Week(weekday=0)+pd.offsets.BDay(0)
#       5 weekly_data['end_of_week'] = weekly_data.index - pd.offsets.Week(weekday=4)+pd.offsets.BDay(0)
#       6 weekly_data
#
# NameError: name 'pd' is not defined
